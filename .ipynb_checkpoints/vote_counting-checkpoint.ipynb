# %%
#take vote format to be ["voter",[-ranking-]]
from numpy import random
import numpy as np
def test_ballot_generator(NVoters,NCandidates):
    ranks=np.array(list(range(1,NCandidates+1)))
    #print(ranks)
    ballots=[]
    for i in range(1,NVoters+1):
        voter="Voter"+str(i)
        ranking=random.permutation(ranks)
        #print(ranking)
        ballots+=[[voter,ranking]]
    return ballots
def count_first_place_votes(candidate,ballots):
    #candidate is an integer here.
    tot=0
    for a in ballots:
        if a[1][candidate]==1:
            tot+=1
    return int(tot)
def balloting_stage(candidates,ballots,tround=1,stage=1,verbose=True):
    total_votes=len(ballots)
    first_place_votes=np.zeros(len(candidates))
    for i in range(len(candidates)):
        first_place_votes[i]=count_first_place_votes(i,ballots)
    if verbose:
        print("balloting round",tround,"stage",stage,": \nfirst place votes:", [(candidates[i],first_place_votes[i]) for i in range(len(candidates))])
    most_votes=0
    #candidate_with_most_votes_index=NaN
    least_votes=sum(first_place_votes)
    #candidate_with_least_votes_index=NaN
    for i in range(len(candidates)):
        if first_place_votes[i]>most_votes:
            most_votes=first_place_votes[i]
            candidate_with_most_votes_index=i
        if first_place_votes[i]<least_votes:
            least_votes=first_place_votes[i]
            candidate_with_least_votes_index=i
    ties_most=[]
    ties_least=[]
    for i in range(len(candidates)):
        if first_place_votes[i]==most_votes:
            ties_most+=[i]
        if first_place_votes[i]==least_votes:
            ties_least+=[i]
    if verbose:
        if len(ties_most)>1:
            print("balloting round",tround,"stage",stage,": \nwarning: tie for first between ",[candidates[i] for i in ties_most])
        if len(ties_least)>1:    
            print("balloting round",tround,"stage",stage,": \nwarning: tie for last between ",[candidates[i] for i in ties_least])
    if ties_least==ties_most:
        if verbose: print("balloting round",tround,"stage",stage,": \nAll way tie")
        return ("tie",list(range(len(candidates))))
    if most_votes>total_votes//2:
        outcome="victory"
        outcome_candidate_indices=[candidate_with_most_votes_index]
        if verbose:
            print("balloting round",tround,"stage",stage,": \n",candidates[candidate_with_most_votes_index],"wins outright with", most_votes,"out of",total_votes)
    else:
        outcome="elimination"
        outcome_candidate_indices=ties_least
        if verbose:
            print("balloting round",tround,"stage",stage,": \n",[candidates[i] for i in ties_least],"are eliminated with", least_votes,"out of",total_votes)
    return (outcome,outcome_candidate_indices)
def ballot_change(ballots,candidate_index,verbose=False,debug=False):
    newballots=[]
    ballot_length=len(ballots[0][1])
    if debug: print("this is ballot_change (before): candidate index",candidate_index,"\nsample ballot:",ballots[0])
    for a in ballots:
        cand_rank=a[1][candidate_index]
        new_ranking=[]
        for i in range(ballot_length):
            if a[1][i]>cand_rank:
                new_ranking+=[a[1][i]-1]
            if a[1][i]<cand_rank:
                new_ranking+=[a[1][i]]
        newballot=[a[0],np.array(new_ranking)]
        if verbose: print("this is ballot_change, adding",newballot)
        newballots+=[newballot]
    if debug: print("this is ballot_change (after): candidate index",candidate_index,"\nsample ballot:",ballots[0])
    return newballots
def candidate_elim(candidates,indices):
    newcands=[]
    for i in range(len(candidates)):
        if i not in indices:
            newcands+=[candidates[i]]
    return newcands
def RCV_recursive(input_candidates,ballots,ranking=[],tround=0,verbose=True,debug=False): #this performs a round, then calls the next round recursively
    if len(input_candidates)==0:
        if verbose: print("voting complete after",tround,"rounds!")
        if verbose: print(ranking)
        return ranking
    tround+=1
    if len(input_candidates)==1:
        if verbose: print("voting complete after",tround,"rounds!")
        ranking+=[(input_candidates[0],tround)]
        if verbose: print(ranking)
        return ranking
    if debug: print("\n\n!~!start of overall round",tround,"\n!~!current candidates are",input_candidates,"\n!~!current ranking is", ranking)
    candidates=[(input_candidates[i],i) for i in range(len(input_candidates))]
    outcome="initiated"
    elim_indices=[]
    newballots=ballots
    newcandidates=candidates
    stage=0
    #stagecandidates=candidates
        #tround+=1
        #roundcandidates=candidate_elim(newcandidates)
    while outcome not in ["victory","tie"]: #perform stage of round
        stage+=1
        if debug: print("\nstage",stage,"checkpoint ")
        for i in elim_indices[::-1]:
            newballots=ballot_change(newballots,i,False,debug)
        if debug: print("stage",stage,"sample ballot",newballots[0])
        newcandidates=candidate_elim(newcandidates,elim_indices)
        if debug: print("stage",stage,"new candidates are:",newcandidates)
        outcome,elim_indices=balloting_stage(newcandidates,newballots,tround,stage,verbose)
        if debug: print(outcome,elim_indices)
    if len(elim_indices)>1:
        ranking+=[(candidates[i][0],tround)for i in elim_indices]
    else:
        winner=candidates[elim_indices[0]][0]
        ranking+=[(winner,tround)]
    candidate_elim_indices=[candidates[i][1] for i in elim_indices]
    next_input_candidates=candidate_elim(input_candidates,candidate_elim_indices)
    if debug: print("next round candidates:",next_input_candidates)
    next_ballots=ballots
    for i in candidate_elim_indices[::-1]:
        next_ballots=ballot_change(next_ballots,i,False,debug)
    if debug: print("next round sample ballot:",next_ballots[0])
    if debug: print("ranking after round",tround,":\n",ranking)
    return RCV_recursive(next_input_candidates,next_ballots,ranking,tround,verbose,debug)
def RCV_wrapper(candidates,ballots,verbosei=True,debugi=False):
    ranking=RCV_recursive(candidates,ballots,ranking=[],tround=0,verbose=verbosei,debug=debugi)
    clean_ranking=[]
    nrounds=ranking[-1][1]
    for i in range(1,nrounds+1):
        roundlist=[]
        for a in ranking:
            if a[1]==i:
                roundlist+=[a[0]]
        if len(roundlist)>1:
            clean_ranking+=[roundlist]
        else:
            clean_ranking+=[roundlist[0]]
    return clean_ranking

# %%
candidates=["Laces", "Owls","Mist","Phantom","Rose","Vinyl"]
completed_trials=0
for i in range(30):
    print("\n\n\n","_"*15,"\nTRIAL NUMBER",i,"\n","_"*15,"\n")
    ballots=test_ballot_generator(50,6)
    ranks=RCV_wrapper(candidates,ballots,debugi=True)
    print(ranks)
    if len(ranks)==len(candidates):
        completed_trials+=1
print("\n\nCOMPLETED TRIALS:",completed_trials)
# Out:
#  _______________
# TRIAL NUMBER 0
#  _______________
#
#
#
# !~!start of overall round 1
# !~!current candidates are ['Laces', 'Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is []
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([5, 6, 2, 3, 4, 1])]
# stage 1 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 1 :
# first place votes: [(('Laces', 0), 6.0), (('Owls', 1), 5.0), (('Mist', 2), 7.0), (('Phantom', 3), 8.0), (('Rose', 4), 11.0), (('Vinyl', 5), 13.0)]
# balloting round 1 stage 1 :
#  [('Owls', 1)] are eliminated with 5.0 out of 50
# elimination [1]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([5, 6, 2, 3, 4, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([5, 6, 2, 3, 4, 1])]
# stage 2 sample ballot ['Voter1', array([5, 2, 3, 4, 1])]
# stage 2 new candidates are: [('Laces', 0), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 2 :
# first place votes: [(('Laces', 0), 7.0), (('Mist', 2), 9.0), (('Phantom', 3), 9.0), (('Rose', 4), 11.0), (('Vinyl', 5), 14.0)]
# balloting round 1 stage 2 :
#  [('Laces', 0)] are eliminated with 7.0 out of 50
# elimination [0]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([5, 2, 3, 4, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([5, 2, 3, 4, 1])]
# stage 3 sample ballot ['Voter1', array([2, 3, 4, 1])]
# stage 3 new candidates are: [('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 3 :
# first place votes: [(('Mist', 2), 9.0), (('Phantom', 3), 10.0), (('Rose', 4), 15.0), (('Vinyl', 5), 16.0)]
# balloting round 1 stage 3 :
#  [('Mist', 2)] are eliminated with 9.0 out of 50
# elimination [0]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# stage 4 sample ballot ['Voter1', array([2, 3, 1])]
# stage 4 new candidates are: [('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 4 :
# first place votes: [(('Phantom', 3), 15.0), (('Rose', 4), 17.0), (('Vinyl', 5), 18.0)]
# balloting round 1 stage 4 :
#  [('Phantom', 3)] are eliminated with 15.0 out of 50
# elimination [0]
#
# stage 5 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# stage 5 sample ballot ['Voter1', array([2, 1])]
# stage 5 new candidates are: [('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 5 :
# first place votes: [(('Rose', 4), 22.0), (('Vinyl', 5), 28.0)]
# balloting round 1 stage 5 :
#  ('Vinyl', 5) wins outright with 28.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([5, 6, 2, 3, 4, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([5, 6, 2, 3, 4, 1])]
# next round sample ballot: ['Voter1', array([5, 2, 3, 4, 1])]
# ranking after round 1 :
#  [('Owls', 1)]
#
#
# !~!start of overall round 2
# !~!current candidates are ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([5, 2, 3, 4, 1])]
# stage 1 new candidates are: [('Laces', 0), ('Mist', 1), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 1 :
# first place votes: [(('Laces', 0), 7.0), (('Mist', 1), 9.0), (('Phantom', 2), 9.0), (('Rose', 3), 11.0), (('Vinyl', 4), 14.0)]
# balloting round 2 stage 1 :
#  [('Laces', 0)] are eliminated with 7.0 out of 50
# elimination [0]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([5, 2, 3, 4, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([5, 2, 3, 4, 1])]
# stage 2 sample ballot ['Voter1', array([2, 3, 4, 1])]
# stage 2 new candidates are: [('Mist', 1), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 2 :
# first place votes: [(('Mist', 1), 9.0), (('Phantom', 2), 10.0), (('Rose', 3), 15.0), (('Vinyl', 4), 16.0)]
# balloting round 2 stage 2 :
#  [('Mist', 1)] are eliminated with 9.0 out of 50
# elimination [0]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# stage 3 sample ballot ['Voter1', array([2, 3, 1])]
# stage 3 new candidates are: [('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 3 :
# first place votes: [(('Phantom', 2), 15.0), (('Rose', 3), 17.0), (('Vinyl', 4), 18.0)]
# balloting round 2 stage 3 :
#  [('Phantom', 2)] are eliminated with 15.0 out of 50
# elimination [0]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# stage 4 sample ballot ['Voter1', array([2, 1])]
# stage 4 new candidates are: [('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 4 :
# first place votes: [(('Rose', 3), 22.0), (('Vinyl', 4), 28.0)]
# balloting round 2 stage 4 :
#  ('Vinyl', 4) wins outright with 28.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([5, 2, 3, 4, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([5, 2, 3, 4, 1])]
# next round sample ballot: ['Voter1', array([4, 2, 3, 1])]
# ranking after round 2 :
#  [('Owls', 1), ('Mist', 2)]
#
#
# !~!start of overall round 3
# !~!current candidates are ['Laces', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([4, 2, 3, 1])]
# stage 1 new candidates are: [('Laces', 0), ('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 1 :
# first place votes: [(('Laces', 0), 8.0), (('Phantom', 1), 13.0), (('Rose', 2), 13.0), (('Vinyl', 3), 16.0)]
# balloting round 3 stage 1 :
#  [('Laces', 0)] are eliminated with 8.0 out of 50
# elimination [0]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([4, 2, 3, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([4, 2, 3, 1])]
# stage 2 sample ballot ['Voter1', array([2, 3, 1])]
# stage 2 new candidates are: [('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 2 :
# first place votes: [(('Phantom', 1), 15.0), (('Rose', 2), 17.0), (('Vinyl', 3), 18.0)]
# balloting round 3 stage 2 :
#  [('Phantom', 1)] are eliminated with 15.0 out of 50
# elimination [0]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# stage 3 sample ballot ['Voter1', array([2, 1])]
# stage 3 new candidates are: [('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 3 :
# first place votes: [(('Rose', 2), 22.0), (('Vinyl', 3), 28.0)]
# balloting round 3 stage 3 :
#  ('Vinyl', 3) wins outright with 28.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([4, 2, 3, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([4, 2, 3, 1])]
# next round sample ballot: ['Voter1', array([3, 2, 1])]
# ranking after round 3 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3)]
#
#
# !~!start of overall round 4
# !~!current candidates are ['Laces', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Phantom', 3)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([3, 2, 1])]
# stage 1 new candidates are: [('Laces', 0), ('Rose', 1), ('Vinyl', 2)]
# balloting round 4 stage 1 :
# first place votes: [(('Laces', 0), 9.0), (('Rose', 1), 17.0), (('Vinyl', 2), 24.0)]
# balloting round 4 stage 1 :
#  [('Laces', 0)] are eliminated with 9.0 out of 50
# elimination [0]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([3, 2, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([3, 2, 1])]
# stage 2 sample ballot ['Voter1', array([2, 1])]
# stage 2 new candidates are: [('Rose', 1), ('Vinyl', 2)]
# balloting round 4 stage 2 :
# first place votes: [(('Rose', 1), 22.0), (('Vinyl', 2), 28.0)]
# balloting round 4 stage 2 :
#  ('Vinyl', 2) wins outright with 28.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 2, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 2, 1])]
# next round sample ballot: ['Voter1', array([2, 1])]
# ranking after round 4 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4)]
#
#
# !~!start of overall round 5
# !~!current candidates are ['Laces', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 1])]
# stage 1 new candidates are: [('Laces', 0), ('Vinyl', 1)]
# balloting round 5 stage 1 :
# first place votes: [(('Laces', 0), 18.0), (('Vinyl', 1), 32.0)]
# balloting round 5 stage 1 :
#  ('Vinyl', 1) wins outright with 32.0 out of 50
# victory [1]
# next round candidates: ['Laces']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 1])]
# next round sample ballot: ['Voter1', array([1])]
# ranking after round 5 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# voting complete after 6 rounds!
# [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5), ('Laces', 6)]
# ['Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl', 'Laces']
#
#
#
#  _______________
# TRIAL NUMBER 1
#  _______________
#
#
#
# !~!start of overall round 1
# !~!current candidates are ['Laces', 'Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is []
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([3, 1, 2, 4, 5, 6])]
# stage 1 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 1 :
# first place votes: [(('Laces', 0), 14.0), (('Owls', 1), 7.0), (('Mist', 2), 11.0), (('Phantom', 3), 7.0), (('Rose', 4), 6.0), (('Vinyl', 5), 5.0)]
# balloting round 1 stage 1 :
#  [('Vinyl', 5)] are eliminated with 5.0 out of 50
# elimination [5]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 5
# sample ballot: ['Voter1', array([3, 1, 2, 4, 5, 6])]
# this is ballot_change (after): candidate index 5
# sample ballot: ['Voter1', array([3, 1, 2, 4, 5, 6])]
# stage 2 sample ballot ['Voter1', array([3, 1, 2, 4, 5])]
# stage 2 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4)]
# balloting round 1 stage 2 :
# first place votes: [(('Laces', 0), 14.0), (('Owls', 1), 8.0), (('Mist', 2), 11.0), (('Phantom', 3), 11.0), (('Rose', 4), 6.0)]
# balloting round 1 stage 2 :
#  [('Rose', 4)] are eliminated with 6.0 out of 50
# elimination [4]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 4
# sample ballot: ['Voter1', array([3, 1, 2, 4, 5])]
# this is ballot_change (after): candidate index 4
# sample ballot: ['Voter1', array([3, 1, 2, 4, 5])]
# stage 3 sample ballot ['Voter1', array([3, 1, 2, 4])]
# stage 3 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3)]
# balloting round 1 stage 3 :
# first place votes: [(('Laces', 0), 15.0), (('Owls', 1), 9.0), (('Mist', 2), 11.0), (('Phantom', 3), 15.0)]
# balloting round 1 stage 3 :
# warning: tie for first between  [('Laces', 0), ('Phantom', 3)]
# balloting round 1 stage 3 :
#  [('Owls', 1)] are eliminated with 9.0 out of 50
# elimination [1]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 2, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 2, 4])]
# stage 4 sample ballot ['Voter1', array([2, 1, 3])]
# stage 4 new candidates are: [('Laces', 0), ('Mist', 2), ('Phantom', 3)]
# balloting round 1 stage 4 :
# first place votes: [(('Laces', 0), 16.0), (('Mist', 2), 15.0), (('Phantom', 3), 19.0)]
# balloting round 1 stage 4 :
#  [('Mist', 2)] are eliminated with 15.0 out of 50
# elimination [1]
#
# stage 5 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3])]
# stage 5 sample ballot ['Voter1', array([1, 2])]
# stage 5 new candidates are: [('Laces', 0), ('Phantom', 3)]
# balloting round 1 stage 5 :
# first place votes: [(('Laces', 0), 24.0), (('Phantom', 3), 26.0)]
# balloting round 1 stage 5 :
#  ('Phantom', 3) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 2, 4, 5, 6])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 2, 4, 5, 6])]
# next round sample ballot: ['Voter1', array([2, 1, 3, 4, 5])]
# ranking after round 1 :
#  [('Owls', 1)]
#
#
# !~!start of overall round 2
# !~!current candidates are ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 1, 3, 4, 5])]
# stage 1 new candidates are: [('Laces', 0), ('Mist', 1), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 1 :
# first place votes: [(('Laces', 0), 15.0), (('Mist', 1), 14.0), (('Phantom', 2), 10.0), (('Rose', 3), 6.0), (('Vinyl', 4), 5.0)]
# balloting round 2 stage 1 :
#  [('Vinyl', 4)] are eliminated with 5.0 out of 50
# elimination [4]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 4
# sample ballot: ['Voter1', array([2, 1, 3, 4, 5])]
# this is ballot_change (after): candidate index 4
# sample ballot: ['Voter1', array([2, 1, 3, 4, 5])]
# stage 2 sample ballot ['Voter1', array([2, 1, 3, 4])]
# stage 2 new candidates are: [('Laces', 0), ('Mist', 1), ('Phantom', 2), ('Rose', 3)]
# balloting round 2 stage 2 :
# first place votes: [(('Laces', 0), 15.0), (('Mist', 1), 15.0), (('Phantom', 2), 14.0), (('Rose', 3), 6.0)]
# balloting round 2 stage 2 :
# warning: tie for first between  [('Laces', 0), ('Mist', 1)]
# balloting round 2 stage 2 :
#  [('Rose', 3)] are eliminated with 6.0 out of 50
# elimination [3]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 3
# sample ballot: ['Voter1', array([2, 1, 3, 4])]
# this is ballot_change (after): candidate index 3
# sample ballot: ['Voter1', array([2, 1, 3, 4])]
# stage 3 sample ballot ['Voter1', array([2, 1, 3])]
# stage 3 new candidates are: [('Laces', 0), ('Mist', 1), ('Phantom', 2)]
# balloting round 2 stage 3 :
# first place votes: [(('Laces', 0), 16.0), (('Mist', 1), 15.0), (('Phantom', 2), 19.0)]
# balloting round 2 stage 3 :
#  [('Mist', 1)] are eliminated with 15.0 out of 50
# elimination [1]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3])]
# stage 4 sample ballot ['Voter1', array([1, 2])]
# stage 4 new candidates are: [('Laces', 0), ('Phantom', 2)]
# balloting round 2 stage 4 :
# first place votes: [(('Laces', 0), 24.0), (('Phantom', 2), 26.0)]
# balloting round 2 stage 4 :
#  ('Phantom', 2) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3, 4, 5])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3, 4, 5])]
# next round sample ballot: ['Voter1', array([1, 2, 3, 4])]
# ranking after round 2 :
#  [('Owls', 1), ('Mist', 2)]
#
#
# !~!start of overall round 3
# !~!current candidates are ['Laces', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 2, 3, 4])]
# stage 1 new candidates are: [('Laces', 0), ('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 1 :
# first place votes: [(('Laces', 0), 18.0), (('Phantom', 1), 14.0), (('Rose', 2), 10.0), (('Vinyl', 3), 8.0)]
# balloting round 3 stage 1 :
#  [('Vinyl', 3)] are eliminated with 8.0 out of 50
# elimination [3]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 3
# sample ballot: ['Voter1', array([1, 2, 3, 4])]
# this is ballot_change (after): candidate index 3
# sample ballot: ['Voter1', array([1, 2, 3, 4])]
# stage 2 sample ballot ['Voter1', array([1, 2, 3])]
# stage 2 new candidates are: [('Laces', 0), ('Phantom', 1), ('Rose', 2)]
# balloting round 3 stage 2 :
# first place votes: [(('Laces', 0), 20.0), (('Phantom', 1), 18.0), (('Rose', 2), 12.0)]
# balloting round 3 stage 2 :
#  [('Rose', 2)] are eliminated with 12.0 out of 50
# elimination [2]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 2, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 2, 3])]
# stage 3 sample ballot ['Voter1', array([1, 2])]
# stage 3 new candidates are: [('Laces', 0), ('Phantom', 1)]
# balloting round 3 stage 3 :
# first place votes: [(('Laces', 0), 24.0), (('Phantom', 1), 26.0)]
# balloting round 3 stage 3 :
#  ('Phantom', 1) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 2, 3, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 2, 3, 4])]
# next round sample ballot: ['Voter1', array([1, 2, 3])]
# ranking after round 3 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3)]
#
#
# !~!start of overall round 4
# !~!current candidates are ['Laces', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Phantom', 3)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 2, 3])]
# stage 1 new candidates are: [('Laces', 0), ('Rose', 1), ('Vinyl', 2)]
# balloting round 4 stage 1 :
# first place votes: [(('Laces', 0), 26.0), (('Rose', 1), 13.0), (('Vinyl', 2), 11.0)]
# balloting round 4 stage 1 :
#  ('Laces', 0) wins outright with 26.0 out of 50
# victory [0]
# next round candidates: ['Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 2, 3])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 2, 3])]
# next round sample ballot: ['Voter1', array([1, 2])]
# ranking after round 4 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Laces', 4)]
#
#
# !~!start of overall round 5
# !~!current candidates are ['Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Laces', 4)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 2])]
# stage 1 new candidates are: [('Rose', 0), ('Vinyl', 1)]
# balloting round 5 stage 1 :
# first place votes: [(('Rose', 0), 25.0), (('Vinyl', 1), 25.0)]
# balloting round 5 stage 1 :
# warning: tie for first between  [('Rose', 0), ('Vinyl', 1)]
# balloting round 5 stage 1 :
# warning: tie for last between  [('Rose', 0), ('Vinyl', 1)]
# balloting round 5 stage 1 :
# All way tie
# tie [0, 1]
# next round candidates: []
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 2])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 2])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1])]
# next round sample ballot: ['Voter1', array([], dtype=float64)]
# ranking after round 5 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Laces', 4), ('Rose', 5), ('Vinyl', 5)]
# voting complete after 5 rounds!
# [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Laces', 4), ('Rose', 5), ('Vinyl', 5)]
# ['Owls', 'Mist', 'Phantom', 'Laces', ['Rose', 'Vinyl']]
#
#
#
#  _______________
# TRIAL NUMBER 2
#  _______________
#
#
#
# !~!start of overall round 1
# !~!current candidates are ['Laces', 'Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is []
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 3, 4, 5, 6, 2])]
# stage 1 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 1 :
# first place votes: [(('Laces', 0), 10.0), (('Owls', 1), 10.0), (('Mist', 2), 4.0), (('Phantom', 3), 11.0), (('Rose', 4), 7.0), (('Vinyl', 5), 8.0)]
# balloting round 1 stage 1 :
#  [('Mist', 2)] are eliminated with 4.0 out of 50
# elimination [2]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 4, 5, 6, 2])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 4, 5, 6, 2])]
# stage 2 sample ballot ['Voter1', array([1, 3, 4, 5, 2])]
# stage 2 new candidates are: [('Laces', 0), ('Owls', 1), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 2 :
# first place votes: [(('Laces', 0), 10.0), (('Owls', 1), 11.0), (('Phantom', 3), 12.0), (('Rose', 4), 8.0), (('Vinyl', 5), 9.0)]
# balloting round 1 stage 2 :
#  [('Rose', 4)] are eliminated with 8.0 out of 50
# elimination [3]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 3
# sample ballot: ['Voter1', array([1, 3, 4, 5, 2])]
# this is ballot_change (after): candidate index 3
# sample ballot: ['Voter1', array([1, 3, 4, 5, 2])]
# stage 3 sample ballot ['Voter1', array([1, 3, 4, 2])]
# stage 3 new candidates are: [('Laces', 0), ('Owls', 1), ('Phantom', 3), ('Vinyl', 5)]
# balloting round 1 stage 3 :
# first place votes: [(('Laces', 0), 12.0), (('Owls', 1), 12.0), (('Phantom', 3), 16.0), (('Vinyl', 5), 10.0)]
# balloting round 1 stage 3 :
#  [('Vinyl', 5)] are eliminated with 10.0 out of 50
# elimination [3]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 3
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# this is ballot_change (after): candidate index 3
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# stage 4 sample ballot ['Voter1', array([1, 2, 3])]
# stage 4 new candidates are: [('Laces', 0), ('Owls', 1), ('Phantom', 3)]
# balloting round 1 stage 4 :
# first place votes: [(('Laces', 0), 14.0), (('Owls', 1), 16.0), (('Phantom', 3), 20.0)]
# balloting round 1 stage 4 :
#  [('Laces', 0)] are eliminated with 14.0 out of 50
# elimination [0]
#
# stage 5 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 2, 3])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 2, 3])]
# stage 5 sample ballot ['Voter1', array([1, 2])]
# stage 5 new candidates are: [('Owls', 1), ('Phantom', 3)]
# balloting round 1 stage 5 :
# first place votes: [(('Owls', 1), 24.0), (('Phantom', 3), 26.0)]
# balloting round 1 stage 5 :
#  ('Phantom', 3) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 3, 4, 5, 6, 2])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 3, 4, 5, 6, 2])]
# next round sample ballot: ['Voter1', array([1, 3, 4, 5, 2])]
# ranking after round 1 :
#  [('Owls', 1)]
#
#
# !~!start of overall round 2
# !~!current candidates are ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 3, 4, 5, 2])]
# stage 1 new candidates are: [('Laces', 0), ('Mist', 1), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 1 :
# first place votes: [(('Laces', 0), 11.0), (('Mist', 1), 7.0), (('Phantom', 2), 12.0), (('Rose', 3), 9.0), (('Vinyl', 4), 11.0)]
# balloting round 2 stage 1 :
#  [('Mist', 1)] are eliminated with 7.0 out of 50
# elimination [1]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 3, 4, 5, 2])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 3, 4, 5, 2])]
# stage 2 sample ballot ['Voter1', array([1, 3, 4, 2])]
# stage 2 new candidates are: [('Laces', 0), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 2 :
# first place votes: [(('Laces', 0), 11.0), (('Phantom', 2), 17.0), (('Rose', 3), 10.0), (('Vinyl', 4), 12.0)]
# balloting round 2 stage 2 :
#  [('Rose', 3)] are eliminated with 10.0 out of 50
# elimination [2]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# stage 3 sample ballot ['Voter1', array([1, 3, 2])]
# stage 3 new candidates are: [('Laces', 0), ('Phantom', 2), ('Vinyl', 4)]
# balloting round 2 stage 3 :
# first place votes: [(('Laces', 0), 14.0), (('Phantom', 2), 22.0), (('Vinyl', 4), 14.0)]
# balloting round 2 stage 3 :
# warning: tie for last between  [('Laces', 0), ('Vinyl', 4)]
# balloting round 2 stage 3 :
#  [('Laces', 0), ('Vinyl', 4)] are eliminated with 14.0 out of 50
# elimination [0, 2]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 2])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 2])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# stage 4 sample ballot ['Voter1', array([1])]
# stage 4 new candidates are: [('Phantom', 2)]
# balloting round 2 stage 4 :
# first place votes: [(('Phantom', 2), 50.0)]
# balloting round 2 stage 4 :
# All way tie
# tie [0]
# next round candidates: ['Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 3, 4, 5, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 3, 4, 5, 2])]
# next round sample ballot: ['Voter1', array([2, 3, 4, 1])]
# ranking after round 2 :
#  [('Owls', 1), ('Laces', 2)]
#
#
# !~!start of overall round 3
# !~!current candidates are ['Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Laces', 2)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 3, 4, 1])]
# stage 1 new candidates are: [('Mist', 0), ('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 1 :
# first place votes: [(('Mist', 0), 10.0), (('Phantom', 1), 14.0), (('Rose', 2), 10.0), (('Vinyl', 3), 16.0)]
# balloting round 3 stage 1 :
# warning: tie for last between  [('Mist', 0), ('Rose', 2)]
# balloting round 3 stage 1 :
#  [('Mist', 0), ('Rose', 2)] are eliminated with 10.0 out of 50
# elimination [0, 2]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# stage 2 sample ballot ['Voter1', array([2, 1])]
# stage 2 new candidates are: [('Phantom', 1), ('Vinyl', 3)]
# balloting round 3 stage 2 :
# first place votes: [(('Phantom', 1), 27.0), (('Vinyl', 3), 23.0)]
# balloting round 3 stage 2 :
#  ('Phantom', 1) wins outright with 27.0 out of 50
# victory [0]
# next round candidates: ['Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 4, 1])]
# next round sample ballot: ['Voter1', array([2, 3, 1])]
# ranking after round 3 :
#  [('Owls', 1), ('Laces', 2), ('Mist', 3)]
#
#
# !~!start of overall round 4
# !~!current candidates are ['Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Laces', 2), ('Mist', 3)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 3, 1])]
# stage 1 new candidates are: [('Phantom', 0), ('Rose', 1), ('Vinyl', 2)]
# balloting round 4 stage 1 :
# first place votes: [(('Phantom', 0), 22.0), (('Rose', 1), 11.0), (('Vinyl', 2), 17.0)]
# balloting round 4 stage 1 :
#  [('Rose', 1)] are eliminated with 11.0 out of 50
# elimination [1]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 3, 1])]
# stage 2 sample ballot ['Voter1', array([2, 1])]
# stage 2 new candidates are: [('Phantom', 0), ('Vinyl', 2)]
# balloting round 4 stage 2 :
# first place votes: [(('Phantom', 0), 27.0), (('Vinyl', 2), 23.0)]
# balloting round 4 stage 2 :
#  ('Phantom', 0) wins outright with 27.0 out of 50
# victory [0]
# next round candidates: ['Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# next round sample ballot: ['Voter1', array([2, 1])]
# ranking after round 4 :
#  [('Owls', 1), ('Laces', 2), ('Mist', 3), ('Phantom', 4)]
#
#
# !~!start of overall round 5
# !~!current candidates are ['Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Laces', 2), ('Mist', 3), ('Phantom', 4)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 1])]
# stage 1 new candidates are: [('Rose', 0), ('Vinyl', 1)]
# balloting round 5 stage 1 :
# first place votes: [(('Rose', 0), 20.0), (('Vinyl', 1), 30.0)]
# balloting round 5 stage 1 :
#  ('Vinyl', 1) wins outright with 30.0 out of 50
# victory [1]
# next round candidates: ['Rose']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 1])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 1])]
# next round sample ballot: ['Voter1', array([1])]
# ranking after round 5 :
#  [('Owls', 1), ('Laces', 2), ('Mist', 3), ('Phantom', 4), ('Vinyl', 5)]
# voting complete after 6 rounds!
# [('Owls', 1), ('Laces', 2), ('Mist', 3), ('Phantom', 4), ('Vinyl', 5), ('Rose', 6)]
# ['Owls', 'Laces', 'Mist', 'Phantom', 'Vinyl', 'Rose']
#
#
#
#  _______________
# TRIAL NUMBER 3
#  _______________
#
#
#
# !~!start of overall round 1
# !~!current candidates are ['Laces', 'Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is []
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([5, 3, 1, 4, 2, 6])]
# stage 1 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 1 :
# first place votes: [(('Laces', 0), 10.0), (('Owls', 1), 2.0), (('Mist', 2), 11.0), (('Phantom', 3), 8.0), (('Rose', 4), 11.0), (('Vinyl', 5), 8.0)]
# balloting round 1 stage 1 :
# warning: tie for first between  [('Mist', 2), ('Rose', 4)]
# balloting round 1 stage 1 :
#  [('Owls', 1)] are eliminated with 2.0 out of 50
# elimination [1]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([5, 3, 1, 4, 2, 6])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([5, 3, 1, 4, 2, 6])]
# stage 2 sample ballot ['Voter1', array([4, 1, 3, 2, 5])]
# stage 2 new candidates are: [('Laces', 0), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 2 :
# first place votes: [(('Laces', 0), 11.0), (('Mist', 2), 12.0), (('Phantom', 3), 8.0), (('Rose', 4), 11.0), (('Vinyl', 5), 8.0)]
# balloting round 1 stage 2 :
# warning: tie for last between  [('Phantom', 3), ('Vinyl', 5)]
# balloting round 1 stage 2 :
#  [('Phantom', 3), ('Vinyl', 5)] are eliminated with 8.0 out of 50
# elimination [2, 4]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 4
# sample ballot: ['Voter1', array([4, 1, 3, 2, 5])]
# this is ballot_change (after): candidate index 4
# sample ballot: ['Voter1', array([4, 1, 3, 2, 5])]
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([4, 1, 3, 2])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([4, 1, 3, 2])]
# stage 3 sample ballot ['Voter1', array([3, 1, 2])]
# stage 3 new candidates are: [('Laces', 0), ('Mist', 2), ('Rose', 4)]
# balloting round 1 stage 3 :
# first place votes: [(('Laces', 0), 15.0), (('Mist', 2), 17.0), (('Rose', 4), 18.0)]
# balloting round 1 stage 3 :
#  [('Laces', 0)] are eliminated with 15.0 out of 50
# elimination [0]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2])]
# stage 4 sample ballot ['Voter1', array([1, 2])]
# stage 4 new candidates are: [('Mist', 2), ('Rose', 4)]
# balloting round 1 stage 4 :
# first place votes: [(('Mist', 2), 24.0), (('Rose', 4), 26.0)]
# balloting round 1 stage 4 :
#  ('Rose', 4) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([5, 3, 1, 4, 2, 6])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([5, 3, 1, 4, 2, 6])]
# next round sample ballot: ['Voter1', array([4, 1, 3, 2, 5])]
# ranking after round 1 :
#  [('Owls', 1)]
#
#
# !~!start of overall round 2
# !~!current candidates are ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([4, 1, 3, 2, 5])]
# stage 1 new candidates are: [('Laces', 0), ('Mist', 1), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 1 :
# first place votes: [(('Laces', 0), 11.0), (('Mist', 1), 12.0), (('Phantom', 2), 8.0), (('Rose', 3), 11.0), (('Vinyl', 4), 8.0)]
# balloting round 2 stage 1 :
# warning: tie for last between  [('Phantom', 2), ('Vinyl', 4)]
# balloting round 2 stage 1 :
#  [('Phantom', 2), ('Vinyl', 4)] are eliminated with 8.0 out of 50
# elimination [2, 4]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 4
# sample ballot: ['Voter1', array([4, 1, 3, 2, 5])]
# this is ballot_change (after): candidate index 4
# sample ballot: ['Voter1', array([4, 1, 3, 2, 5])]
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([4, 1, 3, 2])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([4, 1, 3, 2])]
# stage 2 sample ballot ['Voter1', array([3, 1, 2])]
# stage 2 new candidates are: [('Laces', 0), ('Mist', 1), ('Rose', 3)]
# balloting round 2 stage 2 :
# first place votes: [(('Laces', 0), 15.0), (('Mist', 1), 17.0), (('Rose', 3), 18.0)]
# balloting round 2 stage 2 :
#  [('Laces', 0)] are eliminated with 15.0 out of 50
# elimination [0]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2])]
# stage 3 sample ballot ['Voter1', array([1, 2])]
# stage 3 new candidates are: [('Mist', 1), ('Rose', 3)]
# balloting round 2 stage 3 :
# first place votes: [(('Mist', 1), 24.0), (('Rose', 3), 26.0)]
# balloting round 2 stage 3 :
#  ('Rose', 3) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([4, 1, 3, 2, 5])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([4, 1, 3, 2, 5])]
# next round sample ballot: ['Voter1', array([3, 2, 1, 4])]
# ranking after round 2 :
#  [('Owls', 1), ('Mist', 2)]
#
#
# !~!start of overall round 3
# !~!current candidates are ['Laces', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([3, 2, 1, 4])]
# stage 1 new candidates are: [('Laces', 0), ('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 1 :
# first place votes: [(('Laces', 0), 13.0), (('Phantom', 1), 9.0), (('Rose', 2), 16.0), (('Vinyl', 3), 12.0)]
# balloting round 3 stage 1 :
#  [('Phantom', 1)] are eliminated with 9.0 out of 50
# elimination [1]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 2, 1, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 2, 1, 4])]
# stage 2 sample ballot ['Voter1', array([2, 1, 3])]
# stage 2 new candidates are: [('Laces', 0), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 2 :
# first place votes: [(('Laces', 0), 17.0), (('Rose', 2), 20.0), (('Vinyl', 3), 13.0)]
# balloting round 3 stage 2 :
#  [('Vinyl', 3)] are eliminated with 13.0 out of 50
# elimination [2]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([2, 1, 3])]
# stage 3 sample ballot ['Voter1', array([2, 1])]
# stage 3 new candidates are: [('Laces', 0), ('Rose', 2)]
# balloting round 3 stage 3 :
# first place votes: [(('Laces', 0), 21.0), (('Rose', 2), 29.0)]
# balloting round 3 stage 3 :
#  ('Rose', 2) wins outright with 29.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 2, 1, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 2, 1, 4])]
# next round sample ballot: ['Voter1', array([2, 1, 3])]
# ranking after round 3 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3)]
#
#
# !~!start of overall round 4
# !~!current candidates are ['Laces', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Phantom', 3)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 1, 3])]
# stage 1 new candidates are: [('Laces', 0), ('Rose', 1), ('Vinyl', 2)]
# balloting round 4 stage 1 :
# first place votes: [(('Laces', 0), 17.0), (('Rose', 1), 20.0), (('Vinyl', 2), 13.0)]
# balloting round 4 stage 1 :
#  [('Vinyl', 2)] are eliminated with 13.0 out of 50
# elimination [2]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([2, 1, 3])]
# stage 2 sample ballot ['Voter1', array([2, 1])]
# stage 2 new candidates are: [('Laces', 0), ('Rose', 1)]
# balloting round 4 stage 2 :
# first place votes: [(('Laces', 0), 21.0), (('Rose', 1), 29.0)]
# balloting round 4 stage 2 :
#  ('Rose', 1) wins outright with 29.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 1, 3])]
# next round sample ballot: ['Voter1', array([1, 2])]
# ranking after round 4 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4)]
#
#
# !~!start of overall round 5
# !~!current candidates are ['Laces', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 2])]
# stage 1 new candidates are: [('Laces', 0), ('Vinyl', 1)]
# balloting round 5 stage 1 :
# first place votes: [(('Laces', 0), 32.0), (('Vinyl', 1), 18.0)]
# balloting round 5 stage 1 :
#  ('Laces', 0) wins outright with 32.0 out of 50
# victory [0]
# next round candidates: ['Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# next round sample ballot: ['Voter1', array([1])]
# ranking after round 5 :
#  [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Laces', 5)]
# voting complete after 6 rounds!
# [('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Laces', 5), ('Vinyl', 6)]
# ['Owls', 'Mist', 'Phantom', 'Rose', 'Laces', 'Vinyl']
#
#
#
#  _______________
# TRIAL NUMBER 4
#  _______________
#
#
#
# !~!start of overall round 1
# !~!current candidates are ['Laces', 'Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is []
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([3, 4, 1, 6, 2, 5])]
# stage 1 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 1 :
# first place votes: [(('Laces', 0), 14.0), (('Owls', 1), 7.0), (('Mist', 2), 6.0), (('Phantom', 3), 8.0), (('Rose', 4), 7.0), (('Vinyl', 5), 8.0)]
# balloting round 1 stage 1 :
#  [('Mist', 2)] are eliminated with 6.0 out of 50
# elimination [2]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([3, 4, 1, 6, 2, 5])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([3, 4, 1, 6, 2, 5])]
# stage 2 sample ballot ['Voter1', array([2, 3, 5, 1, 4])]
# stage 2 new candidates are: [('Laces', 0), ('Owls', 1), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 2 :
# first place votes: [(('Laces', 0), 15.0), (('Owls', 1), 7.0), (('Phantom', 3), 8.0), (('Rose', 4), 9.0), (('Vinyl', 5), 11.0)]
# balloting round 1 stage 2 :
#  [('Owls', 1)] are eliminated with 7.0 out of 50
# elimination [1]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 3, 5, 1, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 3, 5, 1, 4])]
# stage 3 sample ballot ['Voter1', array([2, 4, 1, 3])]
# stage 3 new candidates are: [('Laces', 0), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 3 :
# first place votes: [(('Laces', 0), 16.0), (('Phantom', 3), 10.0), (('Rose', 4), 12.0), (('Vinyl', 5), 12.0)]
# balloting round 1 stage 3 :
#  [('Phantom', 3)] are eliminated with 10.0 out of 50
# elimination [1]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 4, 1, 3])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 4, 1, 3])]
# stage 4 sample ballot ['Voter1', array([2, 1, 3])]
# stage 4 new candidates are: [('Laces', 0), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 4 :
# first place votes: [(('Laces', 0), 19.0), (('Rose', 4), 17.0), (('Vinyl', 5), 14.0)]
# balloting round 1 stage 4 :
#  [('Vinyl', 5)] are eliminated with 14.0 out of 50
# elimination [2]
#
# stage 5 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([2, 1, 3])]
# stage 5 sample ballot ['Voter1', array([2, 1])]
# stage 5 new candidates are: [('Laces', 0), ('Rose', 4)]
# balloting round 1 stage 5 :
# first place votes: [(('Laces', 0), 28.0), (('Rose', 4), 22.0)]
# balloting round 1 stage 5 :
#  ('Laces', 0) wins outright with 28.0 out of 50
# victory [0]
# next round candidates: ['Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([3, 4, 1, 6, 2, 5])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([3, 4, 1, 6, 2, 5])]
# next round sample ballot: ['Voter1', array([3, 1, 5, 2, 4])]
# ranking after round 1 :
#  [('Laces', 1)]
#
#
# !~!start of overall round 2
# !~!current candidates are ['Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Laces', 1)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([3, 1, 5, 2, 4])]
# stage 1 new candidates are: [('Owls', 0), ('Mist', 1), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 1 :
# first place votes: [(('Owls', 0), 10.0), (('Mist', 1), 8.0), (('Phantom', 2), 10.0), (('Rose', 3), 10.0), (('Vinyl', 4), 12.0)]
# balloting round 2 stage 1 :
#  [('Mist', 1)] are eliminated with 8.0 out of 50
# elimination [1]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 5, 2, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 5, 2, 4])]
# stage 2 sample ballot ['Voter1', array([2, 4, 1, 3])]
# stage 2 new candidates are: [('Owls', 0), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 2 :
# first place votes: [(('Owls', 0), 11.0), (('Phantom', 2), 11.0), (('Rose', 3), 13.0), (('Vinyl', 4), 15.0)]
# balloting round 2 stage 2 :
# warning: tie for last between  [('Owls', 0), ('Phantom', 2)]
# balloting round 2 stage 2 :
#  [('Owls', 0), ('Phantom', 2)] are eliminated with 11.0 out of 50
# elimination [0, 1]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([2, 4, 1, 3])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([2, 4, 1, 3])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 1, 3])]
# stage 3 sample ballot ['Voter1', array([1, 2])]
# stage 3 new candidates are: [('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 3 :
# first place votes: [(('Rose', 3), 25.0), (('Vinyl', 4), 25.0)]
# balloting round 2 stage 3 :
# warning: tie for first between  [('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 3 :
# warning: tie for last between  [('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 3 :
# All way tie
# tie [0, 1]
# next round candidates: ['Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 5, 2, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 5, 2, 4])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 4, 1, 3])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 4, 1, 3])]
# next round sample ballot: ['Voter1', array([3, 1, 2])]
# ranking after round 2 :
#  [('Laces', 1), ('Owls', 2), ('Mist', 2)]
#
#
# !~!start of overall round 3
# !~!current candidates are ['Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Laces', 1), ('Owls', 2), ('Mist', 2)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([3, 1, 2])]
# stage 1 new candidates are: [('Phantom', 0), ('Rose', 1), ('Vinyl', 2)]
# balloting round 3 stage 1 :
# first place votes: [(('Phantom', 0), 16.0), (('Rose', 1), 18.0), (('Vinyl', 2), 16.0)]
# balloting round 3 stage 1 :
# warning: tie for last between  [('Phantom', 0), ('Vinyl', 2)]
# balloting round 3 stage 1 :
#  [('Phantom', 0), ('Vinyl', 2)] are eliminated with 16.0 out of 50
# elimination [0, 2]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([3, 1, 2])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([3, 1, 2])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 1])]
# stage 2 sample ballot ['Voter1', array([1])]
# stage 2 new candidates are: [('Rose', 1)]
# balloting round 3 stage 2 :
# first place votes: [(('Rose', 1), 50.0)]
# balloting round 3 stage 2 :
# All way tie
# tie [0]
# next round candidates: ['Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2])]
# next round sample ballot: ['Voter1', array([1, 2])]
# ranking after round 3 :
#  [('Laces', 1), ('Owls', 2), ('Mist', 2), ('Phantom', 3)]
#
#
# !~!start of overall round 4
# !~!current candidates are ['Rose', 'Vinyl']
# !~!current ranking is [('Laces', 1), ('Owls', 2), ('Mist', 2), ('Phantom', 3)]
# ...
# stage 2 new candidates are: [('Laces', 0), ('Owls', 1), ('Phantom', 3), ('Vinyl', 5)]
# balloting round 1 stage 2 :
# first place votes: [(('Laces', 0), 10.0), (('Owls', 1), 14.0), (('Phantom', 3), 16.0), (('Vinyl', 5), 10.0)]
# balloting round 1 stage 2 :
# warning: tie for last between  [('Laces', 0), ('Vinyl', 5)]
# balloting round 1 stage 2 :
#  [('Laces', 0), ('Vinyl', 5)] are eliminated with 10.0 out of 50
# elimination [0, 3]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 3
# sample ballot: ['Voter1', array([1, 4, 3, 2])]
# this is ballot_change (after): candidate index 3
# sample ballot: ['Voter1', array([1, 4, 3, 2])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 3, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 3, 2])]
# stage 3 sample ballot ['Voter1', array([2, 1])]
# stage 3 new candidates are: [('Owls', 1), ('Phantom', 3)]
# balloting round 1 stage 3 :
# first place votes: [(('Owls', 1), 24.0), (('Phantom', 3), 26.0)]
# balloting round 1 stage 3 :
#  ('Phantom', 3) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 4, 6, 3, 5, 2])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 4, 6, 3, 5, 2])]
# next round sample ballot: ['Voter1', array([1, 5, 3, 4, 2])]
# ranking after round 1 :
#  [('Owls', 1)]
#
#
# !~!start of overall round 2
# !~!current candidates are ['Laces', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 5, 3, 4, 2])]
# stage 1 new candidates are: [('Laces', 0), ('Mist', 1), ('Phantom', 2), ('Rose', 3), ('Vinyl', 4)]
# balloting round 2 stage 1 :
# first place votes: [(('Laces', 0), 11.0), (('Mist', 1), 7.0), (('Phantom', 2), 15.0), (('Rose', 3), 7.0), (('Vinyl', 4), 10.0)]
# balloting round 2 stage 1 :
# warning: tie for last between  [('Mist', 1), ('Rose', 3)]
# balloting round 2 stage 1 :
#  [('Mist', 1), ('Rose', 3)] are eliminated with 7.0 out of 50
# elimination [1, 3]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 3
# sample ballot: ['Voter1', array([1, 5, 3, 4, 2])]
# this is ballot_change (after): candidate index 3
# sample ballot: ['Voter1', array([1, 5, 3, 4, 2])]
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 4, 3, 2])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 4, 3, 2])]
# stage 2 sample ballot ['Voter1', array([1, 3, 2])]
# stage 2 new candidates are: [('Laces', 0), ('Phantom', 2), ('Vinyl', 4)]
# balloting round 2 stage 2 :
# first place votes: [(('Laces', 0), 15.0), (('Phantom', 2), 22.0), (('Vinyl', 4), 13.0)]
# balloting round 2 stage 2 :
#  [('Vinyl', 4)] are eliminated with 13.0 out of 50
# elimination [2]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 2])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 3, 2])]
# stage 3 sample ballot ['Voter1', array([1, 2])]
# stage 3 new candidates are: [('Laces', 0), ('Phantom', 2)]
# balloting round 2 stage 3 :
# first place votes: [(('Laces', 0), 21.0), (('Phantom', 2), 29.0)]
# balloting round 2 stage 3 :
#  ('Phantom', 2) wins outright with 29.0 out of 50
# victory [1]
# next round candidates: ['Laces', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 5, 3, 4, 2])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 5, 3, 4, 2])]
# next round sample ballot: ['Voter1', array([1, 3, 4, 2])]
# ranking after round 2 :
#  [('Owls', 1), ('Mist', 2)]
#
#
# !~!start of overall round 3
# !~!current candidates are ['Laces', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 3, 4, 2])]
# stage 1 new candidates are: [('Laces', 0), ('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 1 :
# first place votes: [(('Laces', 0), 11.0), (('Phantom', 1), 17.0), (('Rose', 2), 11.0), (('Vinyl', 3), 11.0)]
# balloting round 3 stage 1 :
# warning: tie for last between  [('Laces', 0), ('Rose', 2), ('Vinyl', 3)]
# balloting round 3 stage 1 :
#  [('Laces', 0), ('Rose', 2), ('Vinyl', 3)] are eliminated with 11.0 out of 50
# elimination [0, 2, 3]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 3
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# this is ballot_change (after): candidate index 3
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 2, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 2, 3])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# stage 2 sample ballot ['Voter1', array([1])]
# stage 2 new candidates are: [('Phantom', 1)]
# balloting round 3 stage 2 :
# first place votes: [(('Phantom', 1), 50.0)]
# balloting round 3 stage 2 :
# All way tie
# tie [0]
# next round candidates: ['Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 3, 4, 2])]
# next round sample ballot: ['Voter1', array([2, 3, 1])]
# ranking after round 3 :
#  [('Owls', 1), ('Mist', 2), ('Laces', 3)]
#
#
# !~!start of overall round 4
# !~!current candidates are ['Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Laces', 3)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 3, 1])]
# stage 1 new candidates are: [('Phantom', 0), ('Rose', 1), ('Vinyl', 2)]
# balloting round 4 stage 1 :
# first place votes: [(('Phantom', 0), 21.0), (('Rose', 1), 15.0), (('Vinyl', 2), 14.0)]
# balloting round 4 stage 1 :
#  [('Vinyl', 2)] are eliminated with 14.0 out of 50
# elimination [2]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([2, 3, 1])]
# stage 2 sample ballot ['Voter1', array([1, 2])]
# stage 2 new candidates are: [('Phantom', 0), ('Rose', 1)]
# balloting round 4 stage 2 :
# first place votes: [(('Phantom', 0), 28.0), (('Rose', 1), 22.0)]
# balloting round 4 stage 2 :
#  ('Phantom', 0) wins outright with 28.0 out of 50
# victory [0]
# next round candidates: ['Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 3, 1])]
# next round sample ballot: ['Voter1', array([2, 1])]
# ranking after round 4 :
#  [('Owls', 1), ('Mist', 2), ('Laces', 3), ('Phantom', 4)]
#
#
# !~!start of overall round 5
# !~!current candidates are ['Rose', 'Vinyl']
# !~!current ranking is [('Owls', 1), ('Mist', 2), ('Laces', 3), ('Phantom', 4)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 1])]
# stage 1 new candidates are: [('Rose', 0), ('Vinyl', 1)]
# balloting round 5 stage 1 :
# first place votes: [(('Rose', 0), 28.0), (('Vinyl', 1), 22.0)]
# balloting round 5 stage 1 :
#  ('Rose', 0) wins outright with 28.0 out of 50
# victory [0]
# next round candidates: ['Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 1])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 1])]
# next round sample ballot: ['Voter1', array([1])]
# ranking after round 5 :
#  [('Owls', 1), ('Mist', 2), ('Laces', 3), ('Phantom', 4), ('Rose', 5)]
# voting complete after 6 rounds!
# [('Owls', 1), ('Mist', 2), ('Laces', 3), ('Phantom', 4), ('Rose', 5), ('Vinyl', 6)]
# ['Owls', 'Mist', 'Laces', 'Phantom', 'Rose', 'Vinyl']
#
#
#
#  _______________
# TRIAL NUMBER 29
#  _______________
#
#
#
# !~!start of overall round 1
# !~!current candidates are ['Laces', 'Owls', 'Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is []
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 4, 5, 2, 3, 6])]
# stage 1 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4), ('Vinyl', 5)]
# balloting round 1 stage 1 :
# first place votes: [(('Laces', 0), 16.0), (('Owls', 1), 11.0), (('Mist', 2), 6.0), (('Phantom', 3), 7.0), (('Rose', 4), 6.0), (('Vinyl', 5), 4.0)]
# balloting round 1 stage 1 :
#  [('Vinyl', 5)] are eliminated with 4.0 out of 50
# elimination [5]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 5
# sample ballot: ['Voter1', array([1, 4, 5, 2, 3, 6])]
# this is ballot_change (after): candidate index 5
# sample ballot: ['Voter1', array([1, 4, 5, 2, 3, 6])]
# stage 2 sample ballot ['Voter1', array([1, 4, 5, 2, 3])]
# stage 2 new candidates are: [('Laces', 0), ('Owls', 1), ('Mist', 2), ('Phantom', 3), ('Rose', 4)]
# balloting round 1 stage 2 :
# first place votes: [(('Laces', 0), 16.0), (('Owls', 1), 11.0), (('Mist', 2), 6.0), (('Phantom', 3), 8.0), (('Rose', 4), 9.0)]
# balloting round 1 stage 2 :
#  [('Mist', 2)] are eliminated with 6.0 out of 50
# elimination [2]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 4, 5, 2, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 4, 5, 2, 3])]
# stage 3 sample ballot ['Voter1', array([1, 4, 2, 3])]
# stage 3 new candidates are: [('Laces', 0), ('Owls', 1), ('Phantom', 3), ('Rose', 4)]
# balloting round 1 stage 3 :
# first place votes: [(('Laces', 0), 16.0), (('Owls', 1), 13.0), (('Phantom', 3), 9.0), (('Rose', 4), 12.0)]
# balloting round 1 stage 3 :
#  [('Phantom', 3)] are eliminated with 9.0 out of 50
# elimination [2]
#
# stage 4 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 4, 2, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 4, 2, 3])]
# stage 4 sample ballot ['Voter1', array([1, 3, 2])]
# stage 4 new candidates are: [('Laces', 0), ('Owls', 1), ('Rose', 4)]
# balloting round 1 stage 4 :
# first place votes: [(('Laces', 0), 19.0), (('Owls', 1), 15.0), (('Rose', 4), 16.0)]
# balloting round 1 stage 4 :
#  [('Owls', 1)] are eliminated with 15.0 out of 50
# elimination [1]
#
# stage 5 checkpoint
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 3, 2])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 3, 2])]
# stage 5 sample ballot ['Voter1', array([1, 2])]
# stage 5 new candidates are: [('Laces', 0), ('Rose', 4)]
# balloting round 1 stage 5 :
# first place votes: [(('Laces', 0), 25.0), (('Rose', 4), 25.0)]
# balloting round 1 stage 5 :
# warning: tie for first between  [('Laces', 0), ('Rose', 4)]
# balloting round 1 stage 5 :
# warning: tie for last between  [('Laces', 0), ('Rose', 4)]
# balloting round 1 stage 5 :
# All way tie
# tie [0, 1]
# next round candidates: ['Mist', 'Phantom', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([1, 4, 5, 2, 3, 6])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([1, 4, 5, 2, 3, 6])]
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 4, 2, 3, 5])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 4, 2, 3, 5])]
# next round sample ballot: ['Voter1', array([3, 1, 2, 4])]
# ranking after round 1 :
#  [('Laces', 1), ('Owls', 1)]
#
#
# !~!start of overall round 2
# !~!current candidates are ['Mist', 'Phantom', 'Rose', 'Vinyl']
# !~!current ranking is [('Laces', 1), ('Owls', 1)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([3, 1, 2, 4])]
# stage 1 new candidates are: [('Mist', 0), ('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 2 stage 1 :
# first place votes: [(('Mist', 0), 7.0), (('Phantom', 1), 17.0), (('Rose', 2), 14.0), (('Vinyl', 3), 12.0)]
# balloting round 2 stage 1 :
#  [('Mist', 0)] are eliminated with 7.0 out of 50
# elimination [0]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2, 4])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([3, 1, 2, 4])]
# stage 2 sample ballot ['Voter1', array([1, 2, 3])]
# stage 2 new candidates are: [('Phantom', 1), ('Rose', 2), ('Vinyl', 3)]
# balloting round 2 stage 2 :
# first place votes: [(('Phantom', 1), 18.0), (('Rose', 2), 19.0), (('Vinyl', 3), 13.0)]
# balloting round 2 stage 2 :
#  [('Vinyl', 3)] are eliminated with 13.0 out of 50
# elimination [2]
#
# stage 3 checkpoint
# this is ballot_change (before): candidate index 2
# sample ballot: ['Voter1', array([1, 2, 3])]
# this is ballot_change (after): candidate index 2
# sample ballot: ['Voter1', array([1, 2, 3])]
# stage 3 sample ballot ['Voter1', array([1, 2])]
# stage 3 new candidates are: [('Phantom', 1), ('Rose', 2)]
# balloting round 2 stage 3 :
# first place votes: [(('Phantom', 1), 24.0), (('Rose', 2), 26.0)]
# balloting round 2 stage 3 :
#  ('Rose', 2) wins outright with 26.0 out of 50
# victory [1]
# next round candidates: ['Mist', 'Rose', 'Vinyl']
# this is ballot_change (before): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 2, 4])]
# this is ballot_change (after): candidate index 1
# sample ballot: ['Voter1', array([3, 1, 2, 4])]
# next round sample ballot: ['Voter1', array([2, 1, 3])]
# ranking after round 2 :
#  [('Laces', 1), ('Owls', 1), ('Phantom', 2)]
#
#
# !~!start of overall round 3
# !~!current candidates are ['Mist', 'Rose', 'Vinyl']
# !~!current ranking is [('Laces', 1), ('Owls', 1), ('Phantom', 2)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([2, 1, 3])]
# stage 1 new candidates are: [('Mist', 0), ('Rose', 1), ('Vinyl', 2)]
# balloting round 3 stage 1 :
# first place votes: [(('Mist', 0), 12.0), (('Rose', 1), 20.0), (('Vinyl', 2), 18.0)]
# balloting round 3 stage 1 :
#  [('Mist', 0)] are eliminated with 12.0 out of 50
# elimination [0]
#
# stage 2 checkpoint
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 1, 3])]
# stage 2 sample ballot ['Voter1', array([1, 2])]
# stage 2 new candidates are: [('Rose', 1), ('Vinyl', 2)]
# balloting round 3 stage 2 :
# first place votes: [(('Rose', 1), 31.0), (('Vinyl', 2), 19.0)]
# balloting round 3 stage 2 :
#  ('Rose', 1) wins outright with 31.0 out of 50
# victory [0]
# next round candidates: ['Rose', 'Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([2, 1, 3])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([2, 1, 3])]
# next round sample ballot: ['Voter1', array([1, 2])]
# ranking after round 3 :
#  [('Laces', 1), ('Owls', 1), ('Phantom', 2), ('Mist', 3)]
#
#
# !~!start of overall round 4
# !~!current candidates are ['Rose', 'Vinyl']
# !~!current ranking is [('Laces', 1), ('Owls', 1), ('Phantom', 2), ('Mist', 3)]
#
# stage 1 checkpoint
# stage 1 sample ballot ['Voter1', array([1, 2])]
# stage 1 new candidates are: [('Rose', 0), ('Vinyl', 1)]
# balloting round 4 stage 1 :
# first place votes: [(('Rose', 0), 31.0), (('Vinyl', 1), 19.0)]
# balloting round 4 stage 1 :
#  ('Rose', 0) wins outright with 31.0 out of 50
# victory [0]
# next round candidates: ['Vinyl']
# this is ballot_change (before): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# this is ballot_change (after): candidate index 0
# sample ballot: ['Voter1', array([1, 2])]
# next round sample ballot: ['Voter1', array([1])]
# ranking after round 4 :
#  [('Laces', 1), ('Owls', 1), ('Phantom', 2), ('Mist', 3), ('Rose', 4)]
# voting complete after 5 rounds!
# [('Laces', 1), ('Owls', 1), ('Phantom', 2), ('Mist', 3), ('Rose', 4), ('Vinyl', 5)]
# [['Laces', 'Owls'], 'Phantom', 'Mist', 'Rose', 'Vinyl']
#
#
# COMPLETED TRIALS: 17

# %% [markdown]
# ###
